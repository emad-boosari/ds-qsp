# %% [markdown]
# # Approximate Hybrid Quantum State Preparation for a Sinc Signal

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append("../src")

# %%
import numpy as np
import matplotlib.pyplot as plt

from hybridqsp.transforms import dft, idft
from hybridqsp.transforms import haar_packet_transform, inverse_haar_packet_transform
from hybridqsp.quantum import build_inverse_qphwt_circuit
from hybridqsp.thresholding import top_k_threshold, magnitude_threshold
from hybridqsp.analysis import search_sparse_haar_representations
from hybridqsp.metrics import state_fidelity, trace_distance

# %% [markdown]
# ## Signal Generation
#
# A sinc signal is generated as a representative smooth non-periodic waveform for transform-domain sparsity analysis.

# %%
n = 10    # Number of qubit
N = 2**n  # Number of quantum basis

t = np.linspace(-10, 10, N)

# create sinc signal
x = np.sinc(t)

target_f =  x / np.linalg.norm(x)

# %% [markdown]
# ### Visualization of the Sinc Signal

# %%
plt.figure(figsize=(10, 5))
plt.plot(target_f, label="Original (normalized)", lw=2, color="blue")

plt.title(f"Sinc Signal")
plt.xlabel("Sample index");
plt.ylabel("Amplitude")
plt.grid(True);
plt.legend();
plt.tight_layout();
plt.show()

# %% [markdown]
# ## Compression by Discrete Packet Haar Wavelet Transformation
# ### Classical Sparsity Analysis
#
# The transform-domain coefficients are analyzed in order to identify sparse representations suitable for quantum state preparation.

# %%
results = search_sparse_haar_representations(
    x,
    tolerance=0.04
)
# Out:
# Level=5 | Threshold=4.575e-03 | Nonzero=324 | Sparsity=0.316 | Trace Distance=5.401470e-03 | Fidelity=0.999971
# Level=5 | Threshold=9.150e-03 | Nonzero=244 | Sparsity=0.238 | Trace Distance=1.028043e-02 | Fidelity=0.999894
# Level=5 | Threshold=2.287e-02 | Nonzero=158 | Sparsity=0.154 | Trace Distance=2.234717e-02 | Fidelity=0.999501
# Level=6 | Threshold=3.604e-03 | Nonzero=350 | Sparsity=0.342 | Trace Distance=4.127997e-03 | Fidelity=0.999983
# Level=6 | Threshold=7.209e-03 | Nonzero=266 | Sparsity=0.260 | Trace Distance=7.945041e-03 | Fidelity=0.999937
# Level=6 | Threshold=1.802e-02 | Nonzero=170 | Sparsity=0.166 | Trace Distance=1.801738e-02 | Fidelity=0.999675
# Level=6 | Threshold=3.604e-02 | Nonzero=112 | Sparsity=0.109 | Trace Distance=3.351818e-02 | Fidelity=0.998877
# Level=7 | Threshold=2.857e-03 | Nonzero=358 | Sparsity=0.350 | Trace Distance=3.338950e-03 | Fidelity=0.999989
# Level=7 | Threshold=5.714e-03 | Nonzero=266 | Sparsity=0.260 | Trace Distance=6.786680e-03 | Fidelity=0.999954
# Level=7 | Threshold=1.428e-02 | Nonzero=180 | Sparsity=0.176 | Trace Distance=1.433034e-02 | Fidelity=0.999795
# Level=7 | Threshold=2.857e-02 | Nonzero=128 | Sparsity=0.125 | Trace Distance=2.508876e-02 | Fidelity=0.999371
# Level=8 | Threshold=2.245e-03 | Nonzero=346 | Sparsity=0.338 | Trace Distance=2.424062e-03 | Fidelity=0.999994
# Level=8 | Threshold=4.491e-03 | Nonzero=270 | Sparsity=0.264 | Trace Distance=4.583848e-03 | Fidelity=0.999979
# Level=8 | Threshold=1.123e-02 | Nonzero=188 | Sparsity=0.184 | Trace Distance=1.041760e-02 | Fidelity=0.999891
# Level=8 | Threshold=2.245e-02 | Nonzero=138 | Sparsity=0.135 | Trace Distance=1.885021e-02 | Fidelity=0.999645
# Level=8 | Threshold=4.491e-02 | Nonzero=100 | Sparsity=0.098 | Trace Distance=3.347694e-02 | Fidelity=0.998879
# Level=9 | Threshold=1.816e-03 | Nonzero=418 | Sparsity=0.408 | Trace Distance=1.997189e-03 | Fidelity=0.999996
# Level=9 | Threshold=3.632e-03 | Nonzero=340 | Sparsity=0.332 | Trace Distance=3.756264e-03 | Fidelity=0.999986
# Level=9 | Threshold=9.079e-03 | Nonzero=248 | Sparsity=0.242 | Trace Distance=8.578568e-03 | Fidelity=0.999926
# Level=9 | Threshold=1.816e-02 | Nonzero=196 | Sparsity=0.191 | Trace Distance=1.502523e-02 | Fidelity=0.999774
# Level=9 | Threshold=3.632e-02 | Nonzero=142 | Sparsity=0.139 | Trace Distance=2.886838e-02 | Fidelity=0.999167
# Level=10 | Threshold=2.568e-03 | Nonzero=209 | Sparsity=0.204 | Trace Distance=1.997189e-03 | Fidelity=0.999996
# Level=10 | Threshold=5.136e-03 | Nonzero=170 | Sparsity=0.166 | Trace Distance=3.756264e-03 | Fidelity=0.999986
# Level=10 | Threshold=1.284e-02 | Nonzero=124 | Sparsity=0.121 | Trace Distance=8.578568e-03 | Fidelity=0.999926
# Level=10 | Threshold=2.568e-02 | Nonzero=98 | Sparsity=0.096 | Trace Distance=1.502523e-02 | Fidelity=0.999774
# Level=10 | Threshold=5.136e-02 | Nonzero=71 | Sparsity=0.069 | Trace Distance=2.886838e-02 | Fidelity=0.999167

# %%
# Apply 10-level discrete packet Haar wavelet transformation on sinc signal
level = 8
X_haar = haar_packet_transform(x, level)

# %% [markdown]
# ### Top-k Sparsification
#
# To obtain a sparse transform-domain representation suitable for sparse quantum state preparation, only the largest \(k=110\) Haar-domain coefficients are retained while the remaining coefficients are discarded.

# %%
k = 136
Xr = top_k_threshold(X_haar, k)

# %% [markdown]
# ### Normalization
# The `X_norm` is the output of Phase I.

# %%
X_norm = Xr/np.linalg.norm(Xr)

# %% [markdown]
# ### Classical Signal Reconstruction

# %%
x_rec = inverse_haar_packet_transform(X_norm, level)

# %% [markdown]
# ### Trace Distance

# %%
TD = trace_distance(x_rec, target_f)

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(8, 5))
plt.plot(target_f, 'blue', lw=7, alpha=0.3, label="Target")
plt.plot(x_rec, lw=2, color="red", label="SD-QSP")
plt.title(f"Sinc | L={level} | k={k} |  TD={TD:.4e}")
plt.xlabel("Sample index");
plt.ylabel("Amplitude")
plt.grid(True);
plt.legend();
plt.tight_layout();


plt.show()

# %% [markdown]
# ## Phase II: Quantum Decompression
# The sparse Haar-domain representation is normalized and encoded into a quantum state. The inverse Quantum Packet Haar Wavelet Transform is then applied in order to reconstruct the original signal quantum mechanically.

# %%
from qibo import Circuit, gates
from qibo.models.encodings import sparse_encoder
from qibo.ui import plot_circuit

# %%
# Sparse transform-domain coefficient vector
vec = X_norm

# Indices of nonzero coefficients
nz = np.flatnonzero(vec)

# Number of qubits required for amplitude encoding
nqubits = int(np.log2(len(vec)))

# Construct sparse basis-state representation
# as (bitstring, amplitude) pairs
y = [
    (format(i, f"0{nqubits}b"), vec[i])
    for i in nz
]

# Prepare sparse quantum state using
# the Farias sparse state preparation method
qc = sparse_encoder(
    y,
    method="farias"
)

# Construct inverse quantum Haar packet
# wavelet transform circuit
iqphwt = build_inverse_qphwt_circuit(
    n=nqubits,
    level=level
)

# Apply inverse quantum transformation
# for signal reconstruction
qc.add(
    iqphwt.on_qubits(*range(nqubits))
)

# Print the decomposed circuit statistics
print(
    qc.decompose().decompose().summary()
)
# Out:
# [Qibo 0.3.5|INFO|2026-07-09 16:33:59]: Using numpy backend on /CPU:0
# Circuit depth = 1026
# Total number of gates = 1452
# Number of qubits = 10
# Most common gates:
# cx: 752
# x: 364
# ry: 286
# h: 50
# None

# %% [markdown]
# ### Statevector of the Quantum SQSP and Quantum Decompression

# %%
result = qc()

state = result.state()

# %%
plt.figure(figsize=(8, 5))

plt.plot(target_f, color="blue", lw=7, alpha=0.3, label="Original")
plt.plot(state.real, color="red", lw=2, label="DS-QSP (Haar)") 
plt.title(f"Lossy DS-QSP: Sinc Signal | L={level} | k={k}| TD = {TD:.2e}")

plt.xlabel("Sample Index")
plt.ylabel("Amplitude")

plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

plt.savefig("../figures/Sinc_signal_DHWT.pdf")
plt.show()

# %% [markdown]
# ## Compression by using DFT

# %% [markdown]
# ### Classical Sparsity Analysis
#
# The transform-domain coefficients are analyzed in order to identify sparse representations suitable for quantum state preparation.

# %%
# Apply DFT
X_dft = dft(x)

# %%
freqs = np.fft.fftfreq(len(X_dft), d=1/t)

# %%
plt.figure(figsize=(10,4))

# Real part
plt.fill_between(
    np.arange(len(X_dft)),
    np.real(X_dft),
    color="steelblue",
    alpha=0.45,
    label="Real part"
)

# Imaginary part
markerline, stemlines, baseline = plt.stem(
    np.imag(X_dft),
    linefmt="r-",
    markerfmt="ro",
    basefmt=" "
)

plt.setp(markerline, markersize=3)
plt.setp(stemlines, linewidth=1.2)


markerline.set_label("Imaginary part")
plt.title("Real Coeff v Imaginary Coeff")
plt.xlabel("Frequency index")
plt.ylabel("Coefficient value")
plt.legend(frameon=True)
plt.grid(True, linestyle=":", alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top-k Sparsification

# %%
k = 30
Xr = top_k_threshold(X_dft, k)

# %% [markdown]
# ### Normalization
# The `X_norm` is the output of Phase I.

# %%
X_norm = Xr.real/np.linalg.norm(Xr.real)

# %% [markdown]
# ### Classical Signal Reconstruction

# %%
x_rec = idft(X_norm).real

# %% [markdown]
# ### Trace Distance

# %%
TD = trace_distance(x_rec, target_f)
TD
# Out:
# 0.019569767286535186

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(8, 5))
plt.plot(target_f, 'blue', lw=7, alpha=0.3, label="Target")
plt.plot(x_rec, lw=2, color="red", label="SD-QSP (Fourier)")
plt.title(f"Sinc | k={k} |  TD={TD:.4e}")
plt.xlabel("Sample index");
plt.ylabel("Amplitude")
plt.grid(True);
plt.legend();
plt.tight_layout();

plt.savefig("../figures/Sinc_signal_Fourier.pdf")

plt.show()

# %% [markdown]
# ## Phase II: Quantum Decompression
# The sparse Haar-domain representation is normalized and encoded into a quantum state. The inverse Quantum Packet Haar Wavelet Transform is then applied in order to reconstruct the original signal quantum mechanically.

# %%
from qibo import Circuit, gates
from qibo.models import QFT
from qibo.models.encodings import sparse_encoder
from qibo.ui import plot_circuit

# %%
vec = X_norm

nz = np.flatnonzero(vec)             # Nonzero indices

y = [(format(i, f"0{n}b"), vec[i]) for i in nz]

# ------------------------------------------------
# Sparse encoder circuit
# ------------------------------------------------
circuit = sparse_encoder(y, method="farias")

# ------------------------------------------------
# inverse QFT
# ------------------------------------------------
iqft = QFT(nqubits=n).invert()

circuit.add(iqft.on_qubits(*range(n)))

print(circuit.decompose().decompose().summary())
# Out:
# Circuit depth = 262
# Total number of gates = 478
# Number of qubits = 10
# Most common gates:
# cx: 217
# rz: 135
# ry: 62
# x: 40
# h: 24
# None

# %% [markdown]
# ### Statevector of the Quantum SQSP and Quantum Decompression

# %%
result = circuit()

state = result.state()

# %%
td = trace_distance(target_f, state)
td
# Out:
# 0.019734676694607475

# %%
plt.figure(figsize=(8, 5))
plt.plot(target_f, color="blue", lw=7, alpha=0.3, label="Original")
plt.plot(state.real, lw=2, color="red", label="SD-QSP (Fourier)")
plt.title(f"Lossy DS-QSP: Sinc Signal | k={k}| TD = {TD:.2e}")
plt.title(f"Sinc | k={k} |  TD={td:.4e}")
plt.xlabel("Sample index");
plt.ylabel("Amplitude")
plt.grid(True);
plt.legend();
plt.tight_layout();
plt.savefig("../figures/Sinc_signal_DFT.pdf")
plt.show()

# %% [markdown]
# # Compare their coeffs

# %%
plt.figure(figsize=(8,5))

plt.plot(np.abs(X_dft),
         lw=2,
         color="tab:blue",
         label="DFT")

plt.plot(np.abs(X_haar),
         lw=2,
         color="red",
         label="Haar")

plt.xlabel("Coefficient Index")
plt.ylabel(r"$|X_k|$")
plt.title("Transform Coefficients of the Sinc Signal")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

plt.savefig("../figures/Sinc_transform_coefficients.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import LogLocator, LogFormatterMathtext

# --------------------------------------------------
# Sort coefficients by magnitude
# --------------------------------------------------
dft_sorted = np.sort(np.abs(X_dft))[::-1]
haar_sorted = np.sort(np.abs(X_haar))[::-1]

# Avoid zeros on a logarithmic axis
eps = 1e-12
dft_sorted = np.maximum(dft_sorted, eps)
haar_sorted = np.maximum(haar_sorted, eps)

# --------------------------------------------------
# Number of retained coefficients
# --------------------------------------------------
d_dft = 30
d_haar = 136

# --------------------------------------------------
# Create figure
# --------------------------------------------------
fig, ax = plt.subplots(figsize=(8, 5))

# --------------------------------------------------
# Shaded retained regions
# --------------------------------------------------
ax.axvspan(
    0,
    d_dft,
    color="tab:blue",
    alpha=0.12,
    zorder=0
)

ax.axvspan(
    0,
    d_haar,
    color="tab:red",
    alpha=0.08,
    zorder=0
)

# --------------------------------------------------
# Coefficient decay curves
# --------------------------------------------------
ax.plot(
    dft_sorted,
    lw=2.5,
    color="tab:blue",
    label="DFT"
)

ax.plot(
    haar_sorted,
    lw=2.5,
    color="tab:red",
    label="Haar"
)

# --------------------------------------------------
# Logarithmic y-axis
# --------------------------------------------------
ax.set_yscale("log")

ax.yaxis.set_major_locator(LogLocator(base=10))
ax.yaxis.set_major_formatter(LogFormatterMathtext())

# --------------------------------------------------
# Threshold lines
# --------------------------------------------------
ax.axvline(
    d_dft,
    color="tab:blue",
    linestyle="--",
    lw=1.5,
    alpha=0.7
)

ax.axvline(
    d_haar,
    color="tab:red",
    linestyle="--",
    lw=1.5,
    alpha=0.7
)

# --------------------------------------------------
# Threshold labels
# --------------------------------------------------
ax.text(
    d_dft + 5,
    dft_sorted[d_dft] * 1.5,
    r"$d=30$",
    color="tab:blue",
    fontsize=11
)

ax.text(
    d_haar + 5,
    haar_sorted[d_haar] * 1.5,
    r"$d=136$",
    color="tab:red",
    fontsize=11
)

# --------------------------------------------------
# Labels
# --------------------------------------------------
ax.set_xlabel("Coefficient Rank", fontsize=12)
ax.set_ylabel(r"Coefficient Magnitude $|X_k|$", fontsize=12)

# --------------------------------------------------
# Limits
# --------------------------------------------------
ax.set_xlim(0, len(dft_sorted) - 1)

# --------------------------------------------------
# Grid
# --------------------------------------------------
ax.grid(
    which="major",
    linestyle="--",
    alpha=0.35
)

ax.grid(
    which="minor",
    linestyle=":",
    alpha=0.15
)

# --------------------------------------------------
# Legend
# --------------------------------------------------
ax.legend(
    frameon=True,
    fontsize=11,
    loc="upper right"
)

# --------------------------------------------------
# Tick size
# --------------------------------------------------
ax.tick_params(axis="both", labelsize=11)

# --------------------------------------------------
# Layout and save
# --------------------------------------------------
plt.tight_layout()

plt.savefig(
    "../figures/Sinc_coefficient_decay.pdf",
    dpi=600,
    bbox_inches="tight"
)

plt.show()
