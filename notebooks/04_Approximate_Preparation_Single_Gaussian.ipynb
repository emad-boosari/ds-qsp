# %% [markdown]
# # Approximate Hybrid Quantum State Preparation for a Single-Gaussian Signal

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append("../src")

# %%
import numpy as np
import matplotlib.pyplot as plt

from hybridqsp.transforms import haar_packet_transform, inverse_haar_packet_transform
from hybridqsp.quantum import build_inverse_qphwt_circuit
from hybridqsp.thresholding import top_k_threshold, magnitude_threshold
from hybridqsp.analysis import search_sparse_haar_representations
from hybridqsp.metrics import state_fidelity, trace_distance

# %% [markdown]
# ## Signal Generation
#
# A single-Gaussian signal is generated as a representative smooth localized waveform for transform-domain sparsity analysis.

# %%
n = 15    # Number of qubit
N = 2**n  # Number of quantum basis

x  = np.linspace(-5, 5, N)
mu, sigma, amp = 0.0, 0.8, 1.0
g = amp * np.exp(-(x - mu)**2 / (2.0 * sigma**2))

target_f =  g / np.linalg.norm(g)

# %% [markdown]
# ## Visualization of Single-Gaussian Signal

# %%
plt.figure(figsize=(8, 5))
plt.plot(target_f, label="Original (normalized)", lw=2, color="blue")

plt.title(f"Single-Gaussian")
plt.xlabel("Sample index");
plt.ylabel("Amplitude")
plt.grid(True);
plt.legend();
plt.tight_layout();
plt.show()

# %% [markdown]
# ## Phase I: Classical Compression

# %% [markdown]
# ### Classical Sparsity Analysis

# %%
results = search_sparse_haar_representations(
    g,
    tolerance=0.04
)
# Out:
# Level=7 | Threshold=1.131e-02 | Nonzero=406 | Sparsity=0.012 | Trace Distance=1.665517e-03 | Fidelity=0.999997
# Level=7 | Threshold=2.262e-02 | Nonzero=294 | Sparsity=0.009 | Trace Distance=3.169562e-03 | Fidelity=0.999990
# Level=7 | Threshold=5.655e-02 | Nonzero=184 | Sparsity=0.006 | Trace Distance=6.560219e-03 | Fidelity=0.999957
# Level=7 | Threshold=1.131e-01 | Nonzero=124 | Sparsity=0.004 | Trace Distance=1.085636e-02 | Fidelity=0.999882
# Level=7 | Threshold=2.262e-01 | Nonzero=114 | Sparsity=0.003 | Trace Distance=1.349003e-02 | Fidelity=0.999818
# Level=7 | Threshold=5.655e-01 | Nonzero=100 | Sparsity=0.003 | Trace Distance=2.556209e-02 | Fidelity=0.999347
# Level=8 | Threshold=1.597e-02 | Nonzero=262 | Sparsity=0.008 | Trace Distance=1.761180e-03 | Fidelity=0.999997
# Level=8 | Threshold=3.195e-02 | Nonzero=198 | Sparsity=0.006 | Trace Distance=3.378873e-03 | Fidelity=0.999989
# Level=8 | Threshold=7.987e-02 | Nonzero=130 | Sparsity=0.004 | Trace Distance=7.433201e-03 | Fidelity=0.999945
# Level=8 | Threshold=1.597e-01 | Nonzero=86 | Sparsity=0.003 | Trace Distance=1.346279e-02 | Fidelity=0.999819
# Level=8 | Threshold=3.195e-01 | Nonzero=58 | Sparsity=0.002 | Trace Distance=2.141761e-02 | Fidelity=0.999541
# Level=8 | Threshold=7.987e-01 | Nonzero=50 | Sparsity=0.002 | Trace Distance=3.080610e-02 | Fidelity=0.999051
# Level=9 | Threshold=2.248e-02 | Nonzero=170 | Sparsity=0.005 | Trace Distance=1.986202e-03 | Fidelity=0.999996
# Level=9 | Threshold=4.497e-02 | Nonzero=132 | Sparsity=0.004 | Trace Distance=3.536281e-03 | Fidelity=0.999987
# Level=9 | Threshold=1.124e-01 | Nonzero=92 | Sparsity=0.003 | Trace Distance=7.672413e-03 | Fidelity=0.999941
# Level=9 | Threshold=2.248e-01 | Nonzero=66 | Sparsity=0.002 | Trace Distance=1.370365e-02 | Fidelity=0.999812
# Level=9 | Threshold=4.497e-01 | Nonzero=42 | Sparsity=0.001 | Trace Distance=2.593040e-02 | Fidelity=0.999328
# Level=10 | Threshold=3.120e-02 | Nonzero=126 | Sparsity=0.004 | Trace Distance=2.309719e-03 | Fidelity=0.999995
# Level=10 | Threshold=6.241e-02 | Nonzero=92 | Sparsity=0.003 | Trace Distance=4.311369e-03 | Fidelity=0.999981
# Level=10 | Threshold=1.560e-01 | Nonzero=60 | Sparsity=0.002 | Trace Distance=9.745392e-03 | Fidelity=0.999905
# Level=10 | Threshold=3.120e-01 | Nonzero=46 | Sparsity=0.001 | Trace Distance=1.582212e-02 | Fidelity=0.999750
# Level=10 | Threshold=6.241e-01 | Nonzero=30 | Sparsity=0.001 | Trace Distance=3.104759e-02 | Fidelity=0.999036
# Level=11 | Threshold=4.104e-02 | Nonzero=96 | Sparsity=0.003 | Trace Distance=3.392213e-03 | Fidelity=0.999988
# Level=11 | Threshold=8.209e-02 | Nonzero=72 | Sparsity=0.002 | Trace Distance=5.751045e-03 | Fidelity=0.999967
# Level=11 | Threshold=2.052e-01 | Nonzero=44 | Sparsity=0.001 | Trace Distance=1.241103e-02 | Fidelity=0.999846
# Level=11 | Threshold=4.104e-01 | Nonzero=32 | Sparsity=0.001 | Trace Distance=2.109858e-02 | Fidelity=0.999555
# Level=11 | Threshold=8.209e-01 | Nonzero=22 | Sparsity=0.001 | Trace Distance=3.719583e-02 | Fidelity=0.998616
# Level=12 | Threshold=4.527e-02 | Nonzero=98 | Sparsity=0.003 | Trace Distance=3.737298e-03 | Fidelity=0.999986
# Level=12 | Threshold=9.054e-02 | Nonzero=68 | Sparsity=0.002 | Trace Distance=7.088612e-03 | Fidelity=0.999950
# Level=12 | Threshold=2.263e-01 | Nonzero=46 | Sparsity=0.001 | Trace Distance=1.266766e-02 | Fidelity=0.999840
# Level=12 | Threshold=4.527e-01 | Nonzero=32 | Sparsity=0.001 | Trace Distance=2.236258e-02 | Fidelity=0.999500
# Level=12 | Threshold=9.054e-01 | Nonzero=22 | Sparsity=0.001 | Trace Distance=3.778808e-02 | Fidelity=0.998572
# Level=13 | Threshold=3.623e-02 | Nonzero=98 | Sparsity=0.003 | Trace Distance=3.015623e-03 | Fidelity=0.999991
# Level=13 | Threshold=7.247e-02 | Nonzero=66 | Sparsity=0.002 | Trace Distance=5.520538e-03 | Fidelity=0.999970
# Level=13 | Threshold=1.812e-01 | Nonzero=44 | Sparsity=0.001 | Trace Distance=1.019357e-02 | Fidelity=0.999896
# Level=13 | Threshold=3.623e-01 | Nonzero=32 | Sparsity=0.001 | Trace Distance=1.772115e-02 | Fidelity=0.999686
# Level=13 | Threshold=7.247e-01 | Nonzero=22 | Sparsity=0.001 | Trace Distance=3.173294e-02 | Fidelity=0.998993
# Level=14 | Threshold=2.567e-02 | Nonzero=172 | Sparsity=0.005 | Trace Distance=2.710149e-03 | Fidelity=0.999993
# Level=14 | Threshold=5.133e-02 | Nonzero=130 | Sparsity=0.004 | Trace Distance=4.734821e-03 | Fidelity=0.999978
# Level=14 | Threshold=1.283e-01 | Nonzero=88 | Sparsity=0.003 | Trace Distance=9.738885e-03 | Fidelity=0.999905
# Level=14 | Threshold=2.567e-01 | Nonzero=64 | Sparsity=0.002 | Trace Distance=1.746627e-02 | Fidelity=0.999695
# Level=14 | Threshold=5.133e-01 | Nonzero=44 | Sparsity=0.001 | Trace Distance=3.159446e-02 | Fidelity=0.999002
# Level=15 | Threshold=3.630e-02 | Nonzero=86 | Sparsity=0.003 | Trace Distance=2.710149e-03 | Fidelity=0.999993
# Level=15 | Threshold=7.260e-02 | Nonzero=65 | Sparsity=0.002 | Trace Distance=4.734821e-03 | Fidelity=0.999978
# Level=15 | Threshold=1.815e-01 | Nonzero=44 | Sparsity=0.001 | Trace Distance=9.738885e-03 | Fidelity=0.999905
# Level=15 | Threshold=3.630e-01 | Nonzero=32 | Sparsity=0.001 | Trace Distance=1.746627e-02 | Fidelity=0.999695
# Level=15 | Threshold=7.260e-01 | Nonzero=22 | Sparsity=0.001 | Trace Distance=3.159446e-02 | Fidelity=0.999002

# %%
# Apply 8-level discrete packet Haar wavelet transformation on Single-Gaussian signal
level = 8
X = haar_packet_transform(g, level)

# %%
# apply top-k threshold on the transformed data for k =44
k = 30
Xr = top_k_threshold(X, k)

# %% [markdown]
# ### Normalization

# %%
X_norm = Xr/np.linalg.norm(Xr)

# %% [markdown]
# ### Classical Signal Reconstruction

# %%
x_rec = inverse_haar_packet_transform(X_norm, level)

# %% [markdown]
# ### Trace Distance

# %%
TD = trace_distance(x_rec, target_f)

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(8, 5))
plt.plot(target_f, 'blue', lw=7, alpha=0.3, label="Original")
plt.plot(x_rec, lw=2, color="red", label="DS-QSP")
plt.title(f"Lossy DS-QSP: Single Gaussian Signal | L={level} | k={k} | TD = {TD:.2e}")
plt.xlabel("Sample index");
plt.ylabel("Amplitude")
plt.grid(True);
plt.legend();
plt.tight_layout();
#plt.savefig("../figures/Single-Gaussian_signal_Preparation.pdf")
plt.show()

# %% [markdown]
# ## Phase II: Quantum Decompression
# The sparse Haar-domain representation is normalized and encoded into a quantum state. The inverse Quantum Packet Haar Wavelet Transform is then applied in order to reconstruct the original signal quantum mechanically.

# %%
from qibo import Circuit, gates
from qibo.models.encodings import sparse_encoder
from qibo.ui import plot_circuit

# %%
vec = X_norm

# Nonzero indices
nz = np.flatnonzero(vec)

# Number of qubits
nqubits = int(np.log2(len(vec)))

y = [(format(i, f"0{nqubits}b"), vec[i]) for i in nz]

qc = sparse_encoder(y, method="farias")


iqphwt = build_inverse_qphwt_circuit(
    n=nqubits,
    level=level
)

qc.add(iqphwt.on_qubits(*range(nqubits)))

print(qc.decompose().decompose().summary())
# Out:
# Circuit depth = 252
# Total number of gates = 472
# Number of qubits = 11
# Most common gates:
# cx: 292
# x: 105
# ry: 52
# h: 23
# None

# %% [markdown]
# ## Statevector of the Quantum SQSP and Quantum Decompression

# %%
result = qc()

state = result.state()

# %%
plt.figure(figsize=(8, 5))
plt.plot(target_f, 'blue', lw=7, alpha=0.3, label="Original (normalized)")
plt.plot(state.real, lw=2, color="red", label="Hybrid QSP")
plt.title(f"Sinc | L={level} | thr-k={k} |  TD={TD:.4e}")
plt.xlabel("Sample index");
plt.ylabel("Amplitude")
plt.grid(True);
plt.legend();
plt.tight_layout();
plt.show()
